# %%
import pickle

# %%
InputProcessedFile=pickle.load(open("Scalerprocessedinput.sav","rb"))

# %%
preinput=sc.transform([[25,28,2,1,0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 preinput=sc.transform([[25,28,2,1,0]])
#
# NameError: name 'sc' is not defined

# %%
preinput
# Out:
# array([[-1.01155712, -0.43691555,  0.75107928,  0.98959079, -0.5074631 ]])

# %%
import pickle

# %%
load_model=pickle.load(open("HandlingPreprocessedInput.sav","rb"))

# %%
result=load_model.predict(preinput)

# %%
result
# Out:
# array([3816.21267514])
