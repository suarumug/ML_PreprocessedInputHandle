# %%
import pickle

# %%
scaler=pickle.load(open("ScInputToFile.sav","rb"))
scaleroutput=pickle.load(open("ScOutputToFile.sav","rb"))

# %%
preinput=scaler.transform([[52,28,2,1,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[ 0.91087502, -0.43691555,  0.75107928,  0.98959079, -0.5074631 ]])

# %%
load_model=pickle.load(open("PreprocessedBothFile.sav","rb"))

# %%
Prediction=load_model.predict(preinput)

# %%
Prediction
# Out:
# array([-0.14160934])

# %%
preoutput=scaleroutput.inverse_transform([Prediction])

# %%
preoutput
# Out:
# array([[11556.17253185]])
